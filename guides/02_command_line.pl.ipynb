# %% [markdown]
# # Wiersz poleceń

# %% [markdown]
# Witaj w przewodniku, który zbuduje Twoją pewność siebie w pracy z wierszem poleceń.
#
# Pod koniec tego przewodnika powinieneś umieć pewnie pracować w wierszu poleceń: tworzyć katalogi, przenosić pliki i wiele więcej!

# %% [markdown]
# ## Dla użytkowników Windows PC
#
# Zobacz ten briefing:
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## Dla użytkowników Maca
#
# Zobacz ten briefing:
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# Koniecznie eksperymentuj, żeby zbudować pewność siebie.
#
# ChatGPT, Claude, Gemini, DeepSeek i inne są Twoimi przyjaciółmi! Świetnie radzą sobie z tłumaczeniem dowolnych komend wiersza poleceń ze szczegółami. To szybko stanie się dla Ciebie naturalne.
